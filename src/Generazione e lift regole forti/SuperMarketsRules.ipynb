# %%
import pandas as pd

# %%
dataset = pd.read_csv('supermarkets.csv', sep=',')

# %%
dataset.head()
# Out:
#                                FacilityName         Municipality  LONGITUDE  \
# 0                                    Sobeys       St. Catharines -79.229554
# 1                                   Sobeys               Welland -79.287023
# 2                  Real Canadian Superstore              Grimsby -79.592071
# 3  Outlet Collection at Niagara- Davids Tea  Niagara-on-the-Lake -79.172006
# 4                   No Frills - Supermarket            Fort Erie -78.943567
#
#     LATITUDE                 Address  GSmartID
# 0  43.187516        400 Scott Street  11502418
# 1  43.004156   609 South Pelham Road  11381353
# 2  43.205250  361 South Service Road  11469036
# 3  43.158877         300 Taylor Road  11504411
# 4  42.907641      1135 Thompson Road  11490330

# %%
dataset.shape
# Out:
# (55, 6)

# %%
dataset.isna().any().values
# Out:
# array([False, False, False, False, False, False])

# %%
dataset['FacilityName'] = dataset['FacilityName'].str.strip()

# %%
basket = dataset[dataset['FacilityName']=='Sobeys']
basket
# Out:
#    FacilityName    Municipality  LONGITUDE   LATITUDE                Address  \
# 0        Sobeys  St. Catharines -79.229554  43.187516       400 Scott Street
# 1        Sobeys         Welland -79.287023  43.004156  609 South Pelham Road
# 16       Sobeys   Port Colborne -79.266437  42.904973     287 West Side Road
# 18       Sobeys          Pelham -79.278720  43.047074    110 Highway 20 East
# 29       Sobeys  St. Catharines -79.215968  43.137240    343 Glendale Avenue
# 35       Sobeys         Grimsby -79.568409  43.197482   34 Livingston Avenue
# 49       Sobeys         Lincoln -79.478732  43.181197    4610 Ontario Street
# 52       Sobeys   Niagara Falls -79.098628  43.118691      3714 Portage Road
#
#     GSmartID
# 0   11502418
# 1   11381353
# 16  11322964
# 18  11279813
# 29  11335072
# 35  11492689
# 49  11358340
# 52  11340101

# %%
basket.shape
# Out:
# (8, 6)

# %%
from itertools import combinations

combs = []
for _, row in basket.iterrows():
    elements = row.tolist()
    combs_row = list(combinations(elements,2))
    combs.extend(combs_row)

# %%
combs
# Out:
# [('Sobeys', 'St. Catharines'),
#  ('Sobeys', -79.2295542208932),
#  ('Sobeys', 43.18751636685452),
#  ('Sobeys', '400 Scott Street'),
#  ('Sobeys', 11502418),
#  ('St. Catharines', -79.2295542208932),
#  ('St. Catharines', 43.18751636685452),
#  ('St. Catharines', '400 Scott Street'),
#  ('St. Catharines', 11502418),
#  (-79.2295542208932, 43.18751636685452),
#  (-79.2295542208932, '400 Scott Street'),
#  (-79.2295542208932, 11502418),
#  (43.18751636685452, '400 Scott Street'),
#  (43.18751636685452, 11502418),
#  ('400 Scott Street', 11502418),
#  ('Sobeys', 'Welland'),
#  ('Sobeys', -79.28702307007116),
#  ('Sobeys', 43.00415606496388),
#  ('Sobeys', '609 South Pelham Road'),
#  ('Sobeys', 11381353),
#  ('Welland', -79.28702307007116),
#  ('Welland', 43.00415606496388),
#  ('Welland', '609 South Pelham Road'),
#  ('Welland', 11381353),
#  (-79.28702307007116, 43.00415606496388),
#  (-79.28702307007116, '609 South Pelham Road'),
#  (-79.28702307007116, 11381353),
#  (43.00415606496388, '609 South Pelham Road'),
#  (43.00415606496388, 11381353),
#  ('609 South Pelham Road', 11381353),
#  ('Sobeys', 'Port Colborne'),
#  ('Sobeys', -79.26643742376586),
#  ('Sobeys', 42.904972655011136),
#  ('Sobeys', '287 West Side Road'),
#  ('Sobeys', 11322964),
#  ('Port Colborne', -79.26643742376586),
#  ('Port Colborne', 42.904972655011136),
#  ('Port Colborne', '287 West Side Road'),
#  ('Port Colborne', 11322964),
#  (-79.26643742376586, 42.904972655011136),
#  (-79.26643742376586, '287 West Side Road'),
#  (-79.26643742376586, 11322964),
#  (42.904972655011136, '287 West Side Road'),
#  (42.904972655011136, 11322964),
#  ('287 West Side Road', 11322964),
#  ('Sobeys', 'Pelham'),
#  ('Sobeys', -79.27872021171298),
#  ('Sobeys', 43.04707423506525),
#  ('Sobeys', '110 Highway 20 East'),
#  ('Sobeys', 11279813),
#  ('Pelham', -79.27872021171298),
#  ('Pelham', 43.04707423506525),
#  ('Pelham', '110 Highway 20 East'),
#  ('Pelham', 11279813),
#  (-79.27872021171298, 43.04707423506525),
#  (-79.27872021171298, '110 Highway 20 East'),
#  (-79.27872021171298, 11279813),
#  (43.04707423506525, '110 Highway 20 East'),
#  (43.04707423506525, 11279813),
#  ('110 Highway 20 East', 11279813),
#  ('Sobeys', 'St. Catharines'),
#  ('Sobeys', -79.2159682146955),
#  ('Sobeys', 43.13723997464407),
#  ('Sobeys', '343 Glendale Avenue'),
#  ('Sobeys', 11335072),
#  ('St. Catharines', -79.2159682146955),
#  ('St. Catharines', 43.13723997464407),
#  ('St. Catharines', '343 Glendale Avenue'),
#  ('St. Catharines', 11335072),
#  (-79.2159682146955, 43.13723997464407),
#  (-79.2159682146955, '343 Glendale Avenue'),
#  (-79.2159682146955, 11335072),
#  (43.13723997464407, '343 Glendale Avenue'),
#  (43.13723997464407, 11335072),
#  ('343 Glendale Avenue', 11335072),
#  ('Sobeys', 'Grimsby'),
#  ('Sobeys', -79.56840914865612),
#  ('Sobeys', 43.197482089106906),
#  ('Sobeys', '34 Livingston Avenue'),
#  ('Sobeys', 11492689),
#  ('Grimsby', -79.56840914865612),
#  ('Grimsby', 43.197482089106906),
#  ('Grimsby', '34 Livingston Avenue'),
#  ('Grimsby', 11492689),
#  (-79.56840914865612, 43.197482089106906),
#  (-79.56840914865612, '34 Livingston Avenue'),
#  (-79.56840914865612, 11492689),
#  (43.197482089106906, '34 Livingston Avenue'),
#  (43.197482089106906, 11492689),
#  ('34 Livingston Avenue', 11492689),
#  ('Sobeys', 'Lincoln'),
#  ('Sobeys', -79.47873215825932),
#  ('Sobeys', 43.18119686045125),
#  ('Sobeys', '4610 Ontario Street'),
#  ('Sobeys', 11358340),
#  ('Lincoln', -79.47873215825932),
#  ('Lincoln', 43.18119686045125),
#  ('Lincoln', '4610 Ontario Street'),
#  ('Lincoln', 11358340),
#  (-79.47873215825932, 43.18119686045125),
#  (-79.47873215825932, '4610 Ontario Street'),
#  (-79.47873215825932, 11358340),
#  (43.18119686045125, '4610 Ontario Street'),
#  (43.18119686045125, 11358340),
#  ('4610 Ontario Street', 11358340),
#  ('Sobeys', 'Niagara Falls'),
#  ('Sobeys', -79.09862765886756),
#  ('Sobeys', 43.11869121275181),
#  ('Sobeys', '3714 Portage Road'),
#  ('Sobeys', 11340101),
#  ('Niagara Falls', -79.09862765886756),
#  ('Niagara Falls', 43.11869121275181),
#  ('Niagara Falls', '3714 Portage Road'),
#  ('Niagara Falls', 11340101),
#  (-79.09862765886756, 43.11869121275181),
#  (-79.09862765886756, '3714 Portage Road'),
#  (-79.09862765886756, 11340101),
#  (43.11869121275181, '3714 Portage Road'),
#  (43.11869121275181, 11340101),
#  ('3714 Portage Road', 11340101)]

# %%
sup_threshold = 0.019
n_rows = len(basket)
combinations_support = {}
for combination in combs:
    count = basket.apply(lambda row: all(elem in row.tolist() for elem in combination), axis=1).sum()
    support = count / n_rows
    if support >= sup_threshold:
        combinations_support[combination] = support
combinations_support
# Out:
# {('Sobeys', 'St. Catharines'): 0.25,
#  ('Sobeys', -79.2295542208932): 0.125,
#  ('Sobeys', 43.18751636685452): 0.125,
#  ('Sobeys', '400 Scott Street'): 0.125,
#  ('Sobeys', 11502418): 0.125,
#  ('St. Catharines', -79.2295542208932): 0.125,
#  ('St. Catharines', 43.18751636685452): 0.125,
#  ('St. Catharines', '400 Scott Street'): 0.125,
#  ('St. Catharines', 11502418): 0.125,
#  (-79.2295542208932, 43.18751636685452): 0.125,
#  (-79.2295542208932, '400 Scott Street'): 0.125,
#  (-79.2295542208932, 11502418): 0.125,
#  (43.18751636685452, '400 Scott Street'): 0.125,
#  (43.18751636685452, 11502418): 0.125,
#  ('400 Scott Street', 11502418): 0.125,
#  ('Sobeys', 'Welland'): 0.125,
#  ('Sobeys', -79.28702307007116): 0.125,
#  ('Sobeys', 43.00415606496388): 0.125,
#  ('Sobeys', '609 South Pelham Road'): 0.125,
#  ('Sobeys', 11381353): 0.125,
#  ('Welland', -79.28702307007116): 0.125,
#  ('Welland', 43.00415606496388): 0.125,
#  ('Welland', '609 South Pelham Road'): 0.125,
#  ('Welland', 11381353): 0.125,
#  (-79.28702307007116, 43.00415606496388): 0.125,
#  (-79.28702307007116, '609 South Pelham Road'): 0.125,
#  (-79.28702307007116, 11381353): 0.125,
#  (43.00415606496388, '609 South Pelham Road'): 0.125,
#  (43.00415606496388, 11381353): 0.125,
#  ('609 South Pelham Road', 11381353): 0.125,
#  ('Sobeys', 'Port Colborne'): 0.125,
#  ('Sobeys', -79.26643742376586): 0.125,
#  ('Sobeys', 42.904972655011136): 0.125,
#  ('Sobeys', '287 West Side Road'): 0.125,
#  ('Sobeys', 11322964): 0.125,
#  ('Port Colborne', -79.26643742376586): 0.125,
#  ('Port Colborne', 42.904972655011136): 0.125,
#  ('Port Colborne', '287 West Side Road'): 0.125,
#  ('Port Colborne', 11322964): 0.125,
#  (-79.26643742376586, 42.904972655011136): 0.125,
#  (-79.26643742376586, '287 West Side Road'): 0.125,
#  (-79.26643742376586, 11322964): 0.125,
#  (42.904972655011136, '287 West Side Road'): 0.125,
#  (42.904972655011136, 11322964): 0.125,
#  ('287 West Side Road', 11322964): 0.125,
#  ('Sobeys', 'Pelham'): 0.125,
#  ('Sobeys', -79.27872021171298): 0.125,
#  ('Sobeys', 43.04707423506525): 0.125,
#  ('Sobeys', '110 Highway 20 East'): 0.125,
#  ('Sobeys', 11279813): 0.125,
#  ('Pelham', -79.27872021171298): 0.125,
#  ('Pelham', 43.04707423506525): 0.125,
#  ('Pelham', '110 Highway 20 East'): 0.125,
#  ('Pelham', 11279813): 0.125,
#  (-79.27872021171298, 43.04707423506525): 0.125,
#  (-79.27872021171298, '110 Highway 20 East'): 0.125,
#  (-79.27872021171298, 11279813): 0.125,
#  (43.04707423506525, '110 Highway 20 East'): 0.125,
#  (43.04707423506525, 11279813): 0.125,
#  ('110 Highway 20 East', 11279813): 0.125,
#  ('Sobeys', -79.2159682146955): 0.125,
#  ('Sobeys', 43.13723997464407): 0.125,
#  ('Sobeys', '343 Glendale Avenue'): 0.125,
#  ('Sobeys', 11335072): 0.125,
#  ('St. Catharines', -79.2159682146955): 0.125,
#  ('St. Catharines', 43.13723997464407): 0.125,
#  ('St. Catharines', '343 Glendale Avenue'): 0.125,
#  ('St. Catharines', 11335072): 0.125,
#  (-79.2159682146955, 43.13723997464407): 0.125,
#  (-79.2159682146955, '343 Glendale Avenue'): 0.125,
#  (-79.2159682146955, 11335072): 0.125,
#  (43.13723997464407, '343 Glendale Avenue'): 0.125,
#  (43.13723997464407, 11335072): 0.125,
#  ('343 Glendale Avenue', 11335072): 0.125,
#  ('Sobeys', 'Grimsby'): 0.125,
#  ('Sobeys', -79.56840914865612): 0.125,
#  ('Sobeys', 43.197482089106906): 0.125,
#  ('Sobeys', '34 Livingston Avenue'): 0.125,
#  ('Sobeys', 11492689): 0.125,
#  ('Grimsby', -79.56840914865612): 0.125,
#  ('Grimsby', 43.197482089106906): 0.125,
#  ('Grimsby', '34 Livingston Avenue'): 0.125,
#  ('Grimsby', 11492689): 0.125,
#  (-79.56840914865612, 43.197482089106906): 0.125,
#  (-79.56840914865612, '34 Livingston Avenue'): 0.125,
#  (-79.56840914865612, 11492689): 0.125,
#  (43.197482089106906, '34 Livingston Avenue'): 0.125,
#  (43.197482089106906, 11492689): 0.125,
#  ('34 Livingston Avenue', 11492689): 0.125,
#  ('Sobeys', 'Lincoln'): 0.125,
#  ('Sobeys', -79.47873215825932): 0.125,
#  ('Sobeys', 43.18119686045125): 0.125,
#  ('Sobeys', '4610 Ontario Street'): 0.125,
#  ('Sobeys', 11358340): 0.125,
#  ('Lincoln', -79.47873215825932): 0.125,
#  ('Lincoln', 43.18119686045125): 0.125,
#  ('Lincoln', '4610 Ontario Street'): 0.125,
#  ('Lincoln', 11358340): 0.125,
#  (-79.47873215825932, 43.18119686045125): 0.125,
#  (-79.47873215825932, '4610 Ontario Street'): 0.125,
#  (-79.47873215825932, 11358340): 0.125,
#  (43.18119686045125, '4610 Ontario Street'): 0.125,
#  (43.18119686045125, 11358340): 0.125,
#  ('4610 Ontario Street', 11358340): 0.125,
#  ('Sobeys', 'Niagara Falls'): 0.125,
#  ('Sobeys', -79.09862765886756): 0.125,
#  ('Sobeys', 43.11869121275181): 0.125,
#  ('Sobeys', '3714 Portage Road'): 0.125,
#  ('Sobeys', 11340101): 0.125,
#  ('Niagara Falls', -79.09862765886756): 0.125,
#  ('Niagara Falls', 43.11869121275181): 0.125,
#  ('Niagara Falls', '3714 Portage Road'): 0.125,
#  ('Niagara Falls', 11340101): 0.125,
#  (-79.09862765886756, 43.11869121275181): 0.125,
#  (-79.09862765886756, '3714 Portage Road'): 0.125,
#  (-79.09862765886756, 11340101): 0.125,
#  (43.11869121275181, '3714 Portage Road'): 0.125,
#  (43.11869121275181, 11340101): 0.125,
#  ('3714 Portage Road', 11340101): 0.125}

# %%
confidence_threshold = 0.25
strong_rules = []
for combination, support in combinations_support.items():
    itemset_count = basket.apply(lambda row: all(elem in row.tolist() for elem in combination), axis=1).sum()
    for item in combination:
        antecedent = (item,)
        consequent = tuple([elem for elem in combination if elem != item])
        antecedent_count = basket.apply(lambda row: all(elem in row.tolist() for elem in antecedent), axis=1).sum()
        consequent_count = basket.apply(lambda row: all(elem in row.tolist() for elem in consequent), axis=1).sum()
        confidence = itemset_count / antecedent_count
        lift = itemset_count / (antecedent_count*consequent_count)
        if confidence >= confidence_threshold and lift>=1:
            strong_rules.append((antecedent, consequent, confidence, lift))

# %%
for rule in strong_rules:
    antecedent = rule[0]
    consequent = rule[1]
    confidence = rule[2]
    lift = rule[3]
    print(f"Rule: {antecedent} -> {consequent} (Confidenza: {confidence} Lift: {lift})")
# Out:
# Rule: (-79.2295542208932,) -> (43.18751636685452,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.18751636685452,) -> (-79.2295542208932,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.2295542208932,) -> ('400 Scott Street',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('400 Scott Street',) -> (-79.2295542208932,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.2295542208932,) -> (11502418,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11502418,) -> (-79.2295542208932,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.18751636685452,) -> ('400 Scott Street',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('400 Scott Street',) -> (43.18751636685452,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.18751636685452,) -> (11502418,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11502418,) -> (43.18751636685452,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('400 Scott Street',) -> (11502418,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11502418,) -> ('400 Scott Street',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Welland',) -> (-79.28702307007116,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.28702307007116,) -> ('Welland',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Welland',) -> (43.00415606496388,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.00415606496388,) -> ('Welland',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Welland',) -> ('609 South Pelham Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('609 South Pelham Road',) -> ('Welland',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Welland',) -> (11381353,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11381353,) -> ('Welland',) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.28702307007116,) -> (43.00415606496388,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.00415606496388,) -> (-79.28702307007116,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.28702307007116,) -> ('609 South Pelham Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('609 South Pelham Road',) -> (-79.28702307007116,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.28702307007116,) -> (11381353,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11381353,) -> (-79.28702307007116,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.00415606496388,) -> ('609 South Pelham Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('609 South Pelham Road',) -> (43.00415606496388,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.00415606496388,) -> (11381353,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11381353,) -> (43.00415606496388,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('609 South Pelham Road',) -> (11381353,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11381353,) -> ('609 South Pelham Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Port Colborne',) -> (-79.26643742376586,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.26643742376586,) -> ('Port Colborne',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Port Colborne',) -> (42.904972655011136,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (42.904972655011136,) -> ('Port Colborne',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Port Colborne',) -> ('287 West Side Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('287 West Side Road',) -> ('Port Colborne',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Port Colborne',) -> (11322964,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11322964,) -> ('Port Colborne',) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.26643742376586,) -> (42.904972655011136,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (42.904972655011136,) -> (-79.26643742376586,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.26643742376586,) -> ('287 West Side Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('287 West Side Road',) -> (-79.26643742376586,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.26643742376586,) -> (11322964,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11322964,) -> (-79.26643742376586,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (42.904972655011136,) -> ('287 West Side Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('287 West Side Road',) -> (42.904972655011136,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (42.904972655011136,) -> (11322964,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11322964,) -> (42.904972655011136,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('287 West Side Road',) -> (11322964,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11322964,) -> ('287 West Side Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Pelham',) -> (-79.27872021171298,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.27872021171298,) -> ('Pelham',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Pelham',) -> (43.04707423506525,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.04707423506525,) -> ('Pelham',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Pelham',) -> ('110 Highway 20 East',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('110 Highway 20 East',) -> ('Pelham',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Pelham',) -> (11279813,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11279813,) -> ('Pelham',) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.27872021171298,) -> (43.04707423506525,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.04707423506525,) -> (-79.27872021171298,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.27872021171298,) -> ('110 Highway 20 East',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('110 Highway 20 East',) -> (-79.27872021171298,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.27872021171298,) -> (11279813,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11279813,) -> (-79.27872021171298,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.04707423506525,) -> ('110 Highway 20 East',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('110 Highway 20 East',) -> (43.04707423506525,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.04707423506525,) -> (11279813,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11279813,) -> (43.04707423506525,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('110 Highway 20 East',) -> (11279813,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11279813,) -> ('110 Highway 20 East',) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.2159682146955,) -> (43.13723997464407,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.13723997464407,) -> (-79.2159682146955,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.2159682146955,) -> ('343 Glendale Avenue',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('343 Glendale Avenue',) -> (-79.2159682146955,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.2159682146955,) -> (11335072,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11335072,) -> (-79.2159682146955,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.13723997464407,) -> ('343 Glendale Avenue',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('343 Glendale Avenue',) -> (43.13723997464407,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.13723997464407,) -> (11335072,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11335072,) -> (43.13723997464407,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('343 Glendale Avenue',) -> (11335072,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11335072,) -> ('343 Glendale Avenue',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Grimsby',) -> (-79.56840914865612,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.56840914865612,) -> ('Grimsby',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Grimsby',) -> (43.197482089106906,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.197482089106906,) -> ('Grimsby',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Grimsby',) -> ('34 Livingston Avenue',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('34 Livingston Avenue',) -> ('Grimsby',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Grimsby',) -> (11492689,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11492689,) -> ('Grimsby',) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.56840914865612,) -> (43.197482089106906,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.197482089106906,) -> (-79.56840914865612,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.56840914865612,) -> ('34 Livingston Avenue',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('34 Livingston Avenue',) -> (-79.56840914865612,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.56840914865612,) -> (11492689,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11492689,) -> (-79.56840914865612,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.197482089106906,) -> ('34 Livingston Avenue',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('34 Livingston Avenue',) -> (43.197482089106906,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.197482089106906,) -> (11492689,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11492689,) -> (43.197482089106906,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('34 Livingston Avenue',) -> (11492689,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11492689,) -> ('34 Livingston Avenue',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Lincoln',) -> (-79.47873215825932,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.47873215825932,) -> ('Lincoln',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Lincoln',) -> (43.18119686045125,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.18119686045125,) -> ('Lincoln',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Lincoln',) -> ('4610 Ontario Street',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('4610 Ontario Street',) -> ('Lincoln',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Lincoln',) -> (11358340,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11358340,) -> ('Lincoln',) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.47873215825932,) -> (43.18119686045125,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.18119686045125,) -> (-79.47873215825932,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.47873215825932,) -> ('4610 Ontario Street',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('4610 Ontario Street',) -> (-79.47873215825932,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.47873215825932,) -> (11358340,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11358340,) -> (-79.47873215825932,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.18119686045125,) -> ('4610 Ontario Street',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('4610 Ontario Street',) -> (43.18119686045125,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.18119686045125,) -> (11358340,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11358340,) -> (43.18119686045125,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('4610 Ontario Street',) -> (11358340,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11358340,) -> ('4610 Ontario Street',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Niagara Falls',) -> (-79.09862765886756,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.09862765886756,) -> ('Niagara Falls',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Niagara Falls',) -> (43.11869121275181,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.11869121275181,) -> ('Niagara Falls',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Niagara Falls',) -> ('3714 Portage Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('3714 Portage Road',) -> ('Niagara Falls',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('Niagara Falls',) -> (11340101,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11340101,) -> ('Niagara Falls',) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.09862765886756,) -> (43.11869121275181,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.11869121275181,) -> (-79.09862765886756,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.09862765886756,) -> ('3714 Portage Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('3714 Portage Road',) -> (-79.09862765886756,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (-79.09862765886756,) -> (11340101,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11340101,) -> (-79.09862765886756,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.11869121275181,) -> ('3714 Portage Road',) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('3714 Portage Road',) -> (43.11869121275181,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (43.11869121275181,) -> (11340101,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11340101,) -> (43.11869121275181,) (Confidenza: 1.0 Lift: 1.0)
# Rule: ('3714 Portage Road',) -> (11340101,) (Confidenza: 1.0 Lift: 1.0)
# Rule: (11340101,) -> ('3714 Portage Road',) (Confidenza: 1.0 Lift: 1.0)
